# %%
# Import 需要的套件
import os
import numpy as np
import pandas as pd

# 設定 data_path
dir_data = './data/'

# %%
f_app_train = os.path.join(dir_data, 'application_train.csv')
app_train = pd.read_csv(f_app_train)

# %%
app_train[app_train['CNT_CHILDREN']>18]
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 155369      280108       0         Cash loans           F            N
# 265784      407877       0         Cash loans           F            N
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 155369               Y            19          112500.0    269550.0
# 265784               Y            19          112500.0    135000.0
#
#         AMT_ANNUITY             ...              FLAG_DOCUMENT_18  \
# 155369      13891.5             ...                             0
# 265784       8788.5             ...                             0
#
#        FLAG_DOCUMENT_19 FLAG_DOCUMENT_20 FLAG_DOCUMENT_21  \
# 155369                0                0                0
# 265784                0                0                0
#
#        AMT_REQ_CREDIT_BUREAU_HOUR AMT_REQ_CREDIT_BUREAU_DAY  \
# 155369                        0.0                       0.0
# 265784                        0.0                       0.0
#
#         AMT_REQ_CREDIT_BUREAU_WEEK  AMT_REQ_CREDIT_BUREAU_MON  \
# 155369                         0.0                        0.0
# 265784                         0.0                        0.0
#
#         AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR
# 155369                        0.0                         4.0
# 265784                        0.0                         2.0
#
# [2 rows x 122 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 練習時間

# %% [markdown]
# 觀察有興趣的欄位的資料分佈，並嘗試找出有趣的訊息
# #### Eg
# - 計算任意欄位的平均數及標準差
# - 畫出任意欄位的[直方圖](https://zh.wikipedia.org/zh-tw/%E7%9B%B4%E6%96%B9%E5%9B%BE)
#
# ### Hints:
# - [Descriptive Statistics For pandas Dataframe](https://chrisalbon.com/python/data_wrangling/pandas_dataframe_descriptive_stats/)
# - [pandas 中的繪圖函數](https://amaozhao.gitbooks.io/pandas-notebook/content/pandas%E4%B8%AD%E7%9A%84%E7%BB%98%E5%9B%BE%E5%87%BD%E6%95%B0.html)

# %%
for col in app_train:
    if(app_train[col].dtype!='object'):
        print(col,"\n平均數:",app_train[col].mean(),"\n標準差:",app_train[col].std(),"]")
        print("最小值:",app_train[col].min(),"\n最大值:",app_train[col].max(),"]\n")
        #print(col,app_train[col].mean)
# Out:
# SK_ID_CURR
# 平均數: 278180.518577
# 標準差: 102790.175348 ]
# 最小值: 100002
# 最大值: 456255 ]
#
# TARGET
# 平均數: 0.0807288194569
# 標準差: 0.272418645648 ]
# 最小值: 0
# 最大值: 1 ]
#
# CNT_CHILDREN
# 平均數: 0.417051747742
# 標準差: 0.722121384438 ]
# 最小值: 0
# 最大值: 19 ]
#
# AMT_INCOME_TOTAL
# 平均數: 168797.919297
# 標準差: 237123.146279 ]
# 最小值: 25650.0
# 最大值: 117000000.0 ]
#
# AMT_CREDIT
# 平均數: 599025.999706
# 標準差: 402490.776996 ]
# 最小值: 45000.0
# 最大值: 4050000.0 ]
#
# AMT_ANNUITY
# 平均數: 27108.5739092
# 標準差: 14493.7373151 ]
# 最小值: 1615.5
# 最大值: 258025.5 ]
#
# AMT_GOODS_PRICE
# 平均數: 538396.207429
# 標準差: 369446.46054 ]
# 最小值: 40500.0
# 最大值: 4050000.0 ]
#
# REGION_POPULATION_RELATIVE
# 平均數: 0.0208681120578
# 標準差: 0.0138312801227 ]
# 最小值: 0.00029
# 最大值: 0.072508 ]
#
# DAYS_BIRTH
# 平均數: -16036.9950668
# 標準差: 4363.98863179 ]
# 最小值: -25229
# 最大值: -7489 ]
#
# DAYS_EMPLOYED
# 平均數: 63815.045904
# 標準差: 141275.766519 ]
# 最小值: -17912
# 最大值: 365243 ]
#
# DAYS_REGISTRATION
# 平均數: -4986.12032754
# 標準差: 3522.88632096 ]
# 最小值: -24672.0
# 最大值: 0.0 ]
#
# DAYS_ID_PUBLISH
# 平均數: -2994.20237325
# 標準差: 1509.450419 ]
# 最小值: -7197
# 最大值: 0 ]
#
# OWN_CAR_AGE
# 平均數: 12.0610908187
# 標準差: 11.9448115822 ]
# 最小值: 0.0
# 最大值: 91.0 ]
#
# FLAG_MOBIL
# 平均數: 0.999996748084
# 標準差: 0.00180330701535 ]
# 最小值: 0
# 最大值: 1 ]
#
# FLAG_EMP_PHONE
# 平均數: 0.819889369811
# 標準差: 0.384280198939 ]
# 最小值: 0
# 最大值: 1 ]
#
# FLAG_WORK_PHONE
# 平均數: 0.199368477876
# 標準差: 0.39952622815 ]
# 最小值: 0
# 最大值: 1 ]
#
# FLAG_CONT_MOBILE
# 平均數: 0.998133400106
# 標準差: 0.0431638941424 ]
# 最小值: 0
# 最大值: 1 ]
#
# FLAG_PHONE
# 平均數: 0.281066368358
# 標準差: 0.449520546857 ]
# 最小值: 0
# 最大值: 1 ]
#
# FLAG_EMAIL
# 平均數: 0.0567199222142
# 標準差: 0.231307039723 ]
# 最小值: 0
# 最大值: 1 ]
#
# CNT_FAM_MEMBERS
# 平均數: 2.15266545044
# 標準差: 0.910681569179 ]
# 最小值: 1.0
# 最大值: 20.0 ]
#
# REGION_RATING_CLIENT
# 平均數: 2.05246316392
# 標準差: 0.509033902816 ]
# 最小值: 1
# 最大值: 3 ]
#
# REGION_RATING_CLIENT_W_CITY
# 平均數: 2.03152082365
# 標準差: 0.502737032915 ]
# 最小值: 1
# 最大值: 3 ]
#
# HOUR_APPR_PROCESS_START
# 平均數: 12.0634188696
# 標準差: 3.26583225544 ]
# 最小值: 0
# 最大值: 23 ]
#
# REG_REGION_NOT_LIVE_REGION
# 平均數: 0.0151441737044
# 標準差: 0.122126476282 ]
# 最小值: 0
# 最大值: 1 ]
#
# REG_REGION_NOT_WORK_REGION
# 平均數: 0.0507689155835
# 標準差: 0.219525828797 ]
# 最小值: 0
# 最大值: 1 ]
#
# LIVE_REGION_NOT_WORK_REGION
# 平均數: 0.0406587081438
# 標準差: 0.197498618828 ]
# 最小值: 0
# 最大值: 1 ]
#
# REG_CITY_NOT_LIVE_CITY
# 平均數: 0.0781728133303
# 標準差: 0.268443772373 ]
# 最小值: 0
# 最大值: 1 ]
#
# REG_CITY_NOT_WORK_CITY
# 平均數: 0.230453544751
# 標準差: 0.421123835914 ]
# 最小值: 0
# 最大值: 1 ]
#
# LIVE_CITY_NOT_WORK_CITY
# 平均數: 0.17955455252
# 標準差: 0.383816615386 ]
# 最小值: 0
# 最大值: 1 ]
#
# EXT_SOURCE_1
# 平均數: 0.502129805657
# 標準差: 0.211062249274 ]
# 最小值: 0.0145681324124
# 最大值: 0.962692770561 ]
#
# EXT_SOURCE_2
# 平均數: 0.514392674131
# 標準差: 0.191060154985 ]
# 最小值: 8.17361651888e-08
# 最大值: 0.854999666405 ]
#
# EXT_SOURCE_3
# 平均數: 0.51085290618
# 標準差: 0.194844364464 ]
# 最小值: 0.00052726523871
# 最大值: 0.896009549495 ]
#
# APARTMENTS_AVG
# 平均數: 0.117440499175
# 標準差: 0.1082402913 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# BASEMENTAREA_AVG
# 平均數: 0.0884422190518
# 標準差: 0.0824381587357 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# YEARS_BEGINEXPLUATATION_AVG
# 平均數: 0.977734858162
# 標準差: 0.0592233143584 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# YEARS_BUILD_AVG
# 平均數: 0.752471432593
# 標準差: 0.113279926632 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# COMMONAREA_AVG
# 平均數: 0.0446207154114
# 標準差: 0.0760357450504 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# ELEVATORS_AVG
# 平均數: 0.0789415123242
# 標準差: 0.1345760011 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# ENTRANCES_AVG
# 平均數: 0.149724670068
# 標準差: 0.10004912076 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# FLOORSMAX_AVG
# 平均數: 0.226281907037
# 標準差: 0.144640699548 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# FLOORSMIN_AVG
# 平均數: 0.231893500491
# 標準差: 0.1613802888 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# LANDAREA_AVG
# 平均數: 0.0663331841724
# 標準差: 0.0811836407018 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# LIVINGAPARTMENTS_AVG
# 平均數: 0.100774774951
# 標準差: 0.0925761339605 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# LIVINGAREA_AVG
# 平均數: 0.107399019333
# 標準差: 0.110564523184 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# NONLIVINGAPARTMENTS_AVG
# 平均數: 0.00880867261721
# 標準差: 0.0477316620503 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# NONLIVINGAREA_AVG
# 平均數: 0.0283577570758
# 標準差: 0.0695231833212 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# APARTMENTS_MODE
# 平均數: 0.114231006933
# 標準差: 0.107936039088 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# BASEMENTAREA_MODE
# 平均數: 0.0875432122476
# 標準差: 0.0843071748692 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# YEARS_BEGINEXPLUATATION_MODE
# 平均數: 0.977065372943
# 標準差: 0.0645754370805 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# YEARS_BUILD_MODE
# 平均數: 0.759637322734
# 標準差: 0.110111027342 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# COMMONAREA_MODE
# 平均數: 0.0425531377501
# 標準差: 0.0744445225384 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# ELEVATORS_MODE
# 平均數: 0.0744897361092
# 標準差: 0.132256144151 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# ENTRANCES_MODE
# 平均數: 0.145192658646
# 標準差: 0.10097698816 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# FLOORSMAX_MODE
# 平均數: 0.222315047478
# 標準差: 0.143709406595 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# FLOORSMIN_MODE
# 平均數: 0.228058492551
# 標準差: 0.161159771495 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# LANDAREA_MODE
# 平均數: 0.0649576844566
# 標準差: 0.0817502778084 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# LIVINGAPARTMENTS_MODE
# 平均數: 0.105644856749
# 標準差: 0.0978804465788 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# LIVINGAREA_MODE
# 平均數: 0.105975050437
# 標準差: 0.111845265878 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# NONLIVINGAPARTMENTS_MODE
# 平均數: 0.00807638754428
# 標準差: 0.0462762662198 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# NONLIVINGAREA_MODE
# 平均數: 0.027022319686
# 標準差: 0.0702538590439 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# APARTMENTS_MEDI
# 平均數: 0.117849920766
# 標準差: 0.109075906001 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# BASEMENTAREA_MEDI
# 平均數: 0.0879548546657
# 標準差: 0.0821787495146 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# YEARS_BEGINEXPLUATATION_MEDI
# 平均數: 0.977752264069
# 標準差: 0.0598973185051 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# YEARS_BUILD_MEDI
# 平均數: 0.755746272192
# 標準差: 0.112066309644 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# COMMONAREA_MEDI
# 平均數: 0.0445951017853
# 標準差: 0.0761442622409 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# ELEVATORS_MEDI
# 平均數: 0.0780778443114
# 標準差: 0.134467147691 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# ENTRANCES_MEDI
# 平均數: 0.149212780729
# 標準差: 0.100368394498 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# FLOORSMAX_MEDI
# 平均數: 0.225896590093
# 標準差: 0.145067025919 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# FLOORSMIN_MEDI
# 平均數: 0.231624938049
# 標準差: 0.161933541457 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# LANDAREA_MEDI
# 平均數: 0.0671687490494
# 標準差: 0.0821670102801 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# LIVINGAPARTMENTS_MEDI
# 平均數: 0.101954473241
# 標準差: 0.0936423327115 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# LIVINGAREA_MEDI
# 平均數: 0.108606736049
# 標準差: 0.112260258675 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# NONLIVINGAPARTMENTS_MEDI
# 平均數: 0.00865101333021
# 標準差: 0.0474147279078 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# NONLIVINGAREA_MEDI
# 平均數: 0.0282359205973
# 標準差: 0.0701664815068 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# TOTALAREA_MODE
# 平均數: 0.102546662685
# 標準差: 0.10746232415 ]
# 最小值: 0.0
# 最大值: 1.0 ]
#
# OBS_30_CNT_SOCIAL_CIRCLE
# 平均數: 1.42224542399
# 標準差: 2.40098874611 ]
# 最小值: 0.0
# 最大值: 348.0 ]
#
# DEF_30_CNT_SOCIAL_CIRCLE
# 平均數: 0.143420666253
# 標準差: 0.446698429382 ]
# 最小值: 0.0
# 最大值: 34.0 ]
#
# OBS_60_CNT_SOCIAL_CIRCLE
# 平均數: 1.40529217919
# 標準差: 2.37980335198 ]
# 最小值: 0.0
# 最大值: 344.0 ]
#
# DEF_60_CNT_SOCIAL_CIRCLE
# 平均數: 0.100048941238
# 標準差: 0.362290803976 ]
# 最小值: 0.0
# 最大值: 24.0 ]
#
# DAYS_LAST_PHONE_CHANGE
# 平均數: -962.858788332
# 標準差: 826.808487041 ]
# 最小值: -4292.0
# 最大值: 0.0 ]
#
# FLAG_DOCUMENT_2
# 平均數: 4.2274910491e-05
# 標準差: 0.00650178904549 ]
# 最小值: 0
# 最大值: 1 ]
#
# FLAG_DOCUMENT_3
# 平均數: 0.710023381277
# 標準差: 0.453751968433 ]
# 最小值: 0
# 最大值: 1 ]
#
# FLAG_DOCUMENT_4
# 平均數: 8.12979047904e-05
# 標準差: 0.00901618321655 ]
# 最小值: 0
# 最大值: 1 ]
#
# FLAG_DOCUMENT_5
# 平均數: 0.0151149064586
# 標準差: 0.122010222814 ]
# 最小值: 0
# 最大值: 1 ]
#
# FLAG_DOCUMENT_6
# 平均數: 0.0880553866366
# 標準差: 0.283375892863 ]
# 最小值: 0
# 最大值: 1 ]
#
# FLAG_DOCUMENT_7
# 平均數: 0.000191863055305
# 標準差: 0.013850157677 ]
# 最小值: 0
# 最大值: 1 ]
#
# FLAG_DOCUMENT_8
# 平均數: 0.081375950779
# 標準差: 0.273412048945 ]
# 最小值: 0
# 最大值: 1 ]
#
# FLAG_DOCUMENT_9
# 平均數: 0.00389579559756
# 標準差: 0.0622947108004 ]
# 最小值: 0
# 最大值: 1 ]
#
# FLAG_DOCUMENT_10
# 平均數: 2.27634133413e-05
# 標準差: 0.00477105535407 ]
# 最小值: 0
# 最大值: 1 ]
#
# FLAG_DOCUMENT_11
# 平均數: 0.00391205517851
# 標準差: 0.0624240632668 ]
# 最小值: 0
# 最大值: 1 ]
#
# FLAG_DOCUMENT_12
# 平均數: 6.50383238323e-06
# 標準差: 0.0025502570916 ]
# 最小值: 0
# 最大值: 1 ]
#
# FLAG_DOCUMENT_13
# 平均數: 0.00352507715171
# 標準差: 0.0592677180738 ]
# 最小值: 0
# 最大值: 1 ]
#
# FLAG_DOCUMENT_14
# 平均數: 0.00293648032103
# 標準差: 0.0541097673764 ]
# 最小值: 0
# 最大值: 1 ]
#
# FLAG_DOCUMENT_15
# 平均數: 0.00120971282328
# 標準差: 0.0347599388277 ]
# 最小值: 0
# 最大值: 1 ]
#
# FLAG_DOCUMENT_16
# 平均數: 0.009928100133
# 標準差: 0.0991441623378 ]
# 最小值: 0
# 最大值: 1 ]
#
# FLAG_DOCUMENT_17
# 平均數: 0.000266657127713
# 標準差: 0.0163274887416 ]
# 最小值: 0
# 最大值: 1 ]
#
# FLAG_DOCUMENT_18
# 平均數: 0.00812979047904
# 標準差: 0.0897982361094 ]
# 最小值: 0
# 最大值: 1 ]
#
# FLAG_DOCUMENT_19
# 平均數: 0.000595100663066
# 標準差: 0.0243874650659 ]
# 最小值: 0
# 最大值: 1 ]
#
# FLAG_DOCUMENT_20
# 平均數: 0.000507298925892
# 標準差: 0.0225176202684 ]
# 最小值: 0
# 最大值: 1 ]
#
# FLAG_DOCUMENT_21
# 平均數: 0.000334947367736
# 標準差: 0.0182985318224 ]
# 最小值: 0
# 最大值: 1 ]
#
# AMT_REQ_CREDIT_BUREAU_HOUR
# 平均數: 0.00640244819393
# 標準差: 0.0838491284475 ]
# 最小值: 0.0
# 最大值: 4.0 ]
#
# AMT_REQ_CREDIT_BUREAU_DAY
# 平均數: 0.00700021053265
# 標準差: 0.110757406324 ]
# 最小值: 0.0
# 最大值: 9.0 ]
#
# AMT_REQ_CREDIT_BUREAU_WEEK
# 平均數: 0.0343619356973
# 標準差: 0.204684875813 ]
# 最小值: 0.0
# 最大值: 8.0 ]
#
# AMT_REQ_CREDIT_BUREAU_MON
# 平均數: 0.267395260008
# 標準差: 0.916002396153 ]
# 最小值: 0.0
# 最大值: 27.0 ]
#
# AMT_REQ_CREDIT_BUREAU_QRT
# 平均數: 0.265474149598
# 標準差: 0.794055648321 ]
# 最小值: 0.0
# 最大值: 261.0 ]
#
# AMT_REQ_CREDIT_BUREAU_YEAR
# 平均數: 1.89997443532
# 標準差: 1.86929499818 ]
# 最小值: 0.0
# 最大值: 25.0 ]

# %%
plt.hist(app_train['AMT_INCOME_TOTAL'])
plt.show()
